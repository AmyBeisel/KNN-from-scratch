# %% [markdown]
# Prepare data

# %%
import numpy as np
from KNN import k_nearest_neighbors

from sklearn import datasets
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# %%
iris_data = datasets.load_iris()
data = iris_data.data
target = iris_data.target

# %%
# Train/Test splits
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.3)

# %%
print(X_train.shape)
print(X_train[0])
print(y_train.shape)
print(y_train)
# Out:
# (105, 4)
# [6.5 3.  5.2 2. ]
# (105,)
# [2 1 1 0 0 1 2 1 1 1 2 0 0 2 1 2 0 0 0 1 2 0 1 0 1 0 0 2 0 2 0 2 2 0 2 1 1
#  1 1 2 0 2 0 1 2 0 1 0 1 0 2 0 0 2 2 0 0 2 0 2 2 2 0 0 1 1 0 1 0 0 2 0 2 0
#  2 1 2 0 0 1 2 0 1 1 0 1 2 0 0 0 2 1 1 2 2 1 1 2 1 1 1 1 0 1 2]

# %%
#2D 
cmap = ListedColormap(["red", "green", "blue"])
plt.figure()
plt.scatter(data[:, 0], data[:,1], c=target, cmap=cmap, s=30)
plt.show()

# %% [markdown]
# Scikit-learn KNN Classifier

# %%
# Sklearn-learn KNN Classifier
# Instantiate model
model_SKlean = KNeighborsClassifier(n_neighbors=3)

# %%
# Fit
model_SKlean.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
# Prediction
predict = model_SKlean.predict(X_test)

# %%
# Accuracy Score
print("Scikit-learn KNN classifier accuracy:{0:.3f}".format(accuracy_score(y_test, predict)))
# Out:
# Scikit-learn KNN classifier accuracy:0.978

# %%
# y_pred
y_pred = model_SKlean.predict([X_test[0]])
print("y_pred", y_pred)
# Out:
# y_pred [0]

# %% [markdown]
# Build model from scratch

# %%
my_model = k_nearest_neighbors(k = 3)
my_model.knn_fit(X_train, y_train)
predictions = my_model.knn_predict(X_test)

# %%
acc = np.sum(predictions == y_test) / len(y_test)
print("My model from scratch KNN classifier accuracy:{0:.3}".format(acc))
# Out:
# My model from scratch KNN classifier accuracy:0.978

# %%
# y_pred
y_pred = my_model.knn_predict([X_test[0]])
print("y_pred", y_pred)
# Out:
# y_pred [0]
